# %%
# import commands

import pandas as pd
import numpy as np
from scripts import project_functions_gc as pfg
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %matplotlib inline

# %%
mh = pfg.load_and_process('../../data/raw/mentalhealthintech.csv')
mh
# Out:
#     treatment work_interfere  benefits  care_options  wellness_program  \
# 0         Yes      Sometimes         1             1                 2
# 1         Yes          Often         1             1                 2
# 2         Yes         Rarely         1             0                 0
# 3          No            N/A         0             0                 2
# 4         Yes         Rarely         1             1                 0
# ..        ...            ...       ...           ...               ...
# 878       Yes      Sometimes         1             1                 1
# 879       Yes            N/A         2             2                 2
# 880       Yes          Often         1             1                 2
# 881       Yes      Sometimes         1             1                 2
# 882        No            N/A         2             1                 2
#
#      seek_help condition resources               knowledge
# 0            2       Yes      Poor           Knowledgeable
# 1            2       Yes      Poor           Knowledgeable
# 2            1       Yes      Good  Somewhat knowledgeable
# 3            0        No      Poor       Not knowledgeable
# 4            0       Yes      Poor  Somewhat knowledgeable
# ..         ...       ...       ...                     ...
# 878          2       Yes      Good           Knowledgeable
# 879          2        No      Poor           Knowledgeable
# 880          2       Yes      Poor           Knowledgeable
# 881          2       Yes      Poor           Knowledgeable
# 882          2        No      Poor           Knowledgeable
#
# [883 rows x 9 columns]

# %%
mh = mh.replace({0:"Don't know",1:'Yes', 2:'No'})
mh
# Out:
#     treatment work_interfere    benefits care_options wellness_program  \
# 0         Yes      Sometimes         Yes          Yes               No
# 1         Yes          Often         Yes          Yes               No
# 2         Yes         Rarely         Yes   Don't know       Don't know
# 3          No            N/A  Don't know   Don't know               No
# 4         Yes         Rarely         Yes          Yes       Don't know
# ..        ...            ...         ...          ...              ...
# 878       Yes      Sometimes         Yes          Yes              Yes
# 879       Yes            N/A          No           No               No
# 880       Yes          Often         Yes          Yes               No
# 881       Yes      Sometimes         Yes          Yes               No
# 882        No            N/A          No          Yes               No
#
#       seek_help condition resources               knowledge
# 0            No       Yes      Poor           Knowledgeable
# 1            No       Yes      Poor           Knowledgeable
# 2           Yes       Yes      Good  Somewhat knowledgeable
# 3    Don't know        No      Poor       Not knowledgeable
# 4    Don't know       Yes      Poor  Somewhat knowledgeable
# ..          ...       ...       ...                     ...
# 878          No       Yes      Good           Knowledgeable
# 879          No        No      Poor           Knowledgeable
# 880          No       Yes      Poor           Knowledgeable
# 881          No       Yes      Poor           Knowledgeable
# 882          No        No      Poor           Knowledgeable
#
# [883 rows x 9 columns]

# %%
mh.to_csv("../../data/processed/mh_processed_gc.csv")
