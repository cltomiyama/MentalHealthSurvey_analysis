# %%
# import commands

import pandas as pd
import numpy as np

# %% [markdown]
# # Analysis Pipeline

# %% [markdown]
# ## Loading

# %%
mh = pd.read_csv("../../data/raw/mentalhealthintech.csv")
mh
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0      8/27/2014 11:29   37  Female   United States    IL           NaN
# 1      8/27/2014 11:29   44       M   United States    IN           NaN
# 2      8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3      8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4      8/27/2014 11:30   31    Male   United States    TX           NaN
# ...                ...  ...     ...             ...   ...           ...
# 1254   9/12/2015 11:17   26    male  United Kingdom   NaN            No
# 1255    9/26/2015 1:07   32    Male   United States    IL            No
# 1256   11/7/2015 12:36   34    male   United States    CA            No
# 1257  11/30/2015 21:25   46       f   United States    NC            No
# 1258    2/1/2016 23:04   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 0                No       Yes          Often          25-Jun  ...
# 1                No        No         Rarely  More than 1000  ...
# 2                No        No         Rarely          25-Jun  ...
# 3               Yes       Yes          Often          26-100  ...
# 4                No        No          Never         100-500  ...
# ...             ...       ...            ...             ...  ...
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# 0          Somewhat easy                        No                      No
# 1             Don't know                     Maybe                      No
# 2     Somewhat difficult                        No                      No
# 3     Somewhat difficult                       Yes                     Yes
# 4             Don't know                        No                      No
# ...                  ...                       ...                     ...
# 1254       Somewhat easy                        No                      No
# 1255  Somewhat difficult                        No                      No
# 1256  Somewhat difficult                       Yes                     Yes
# 1257          Don't know                       Yes                      No
# 1258          Don't know                     Maybe                      No
#
#          coworkers    supervisor mental_health_interview  \
# 0     Some of them           Yes                      No
# 1               No            No                      No
# 2              Yes           Yes                     Yes
# 3     Some of them            No                   Maybe
# 4     Some of them           Yes                     Yes
# ...            ...           ...                     ...
# 1254  Some of them  Some of them                      No
# 1255  Some of them           Yes                      No
# 1256            No            No                      No
# 1257            No            No                      No
# 1258  Some of them            No                      No
#
#      phys_health_interview mental_vs_physical obs_consequence comments
# 0                    Maybe                Yes              No      NaN
# 1                       No         Don't know              No      NaN
# 2                      Yes                 No              No      NaN
# 3                    Maybe                 No             Yes      NaN
# 4                      Yes         Don't know              No      NaN
# ...                    ...                ...             ...      ...
# 1254                    No         Don't know              No      NaN
# 1255                    No                Yes              No      NaN
# 1256                    No                 No              No      NaN
# 1257                    No                 No              No      NaN
# 1258                    No         Don't know              No      NaN
#
# [1259 rows x 27 columns]

# %%
mh.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# ## Cleaning

# %%
# keeping only desired/relevant columns
mh_cleaned = mh[['self_employed', 'family_history', 'treatment', 'work_interfere', 'tech_company', 'benefits', 'care_options', 'wellness_program', 'seek_help']]
mh_cleaned
# Out:
#      self_employed family_history treatment work_interfere tech_company  \
# 0              NaN             No       Yes          Often          Yes
# 1              NaN             No        No         Rarely           No
# 2              NaN             No        No         Rarely          Yes
# 3              NaN            Yes       Yes          Often          Yes
# 4              NaN             No        No          Never          Yes
# ...            ...            ...       ...            ...          ...
# 1254            No             No       Yes            NaN          Yes
# 1255            No            Yes       Yes          Often          Yes
# 1256            No            Yes       Yes      Sometimes          Yes
# 1257            No             No        No            NaN          Yes
# 1258            No            Yes       Yes      Sometimes           No
#
#         benefits care_options wellness_program   seek_help
# 0            Yes     Not sure               No         Yes
# 1     Don't know           No       Don't know  Don't know
# 2             No           No               No          No
# 3             No          Yes               No          No
# 4            Yes           No       Don't know  Don't know
# ...          ...          ...              ...         ...
# 1254          No           No               No          No
# 1255         Yes          Yes               No          No
# 1256         Yes          Yes               No          No
# 1257          No          Yes               No          No
# 1258         Yes          Yes               No          No
#
# [1259 rows x 9 columns]

# %%
# keepings respondents that work for a company/employer
mh_cleaned = mh_cleaned[mh_cleaned['self_employed'].str.find('Yes') == -1]
mh_cleaned
# Out:
#      self_employed family_history treatment work_interfere tech_company  \
# 20              No            Yes       Yes      Sometimes          Yes
# 22              No             No       Yes          Often          Yes
# 23              No             No       Yes          Never           No
# 24              No            Yes       Yes         Rarely          Yes
# 25              No            Yes       Yes      Sometimes           No
# ...            ...            ...       ...            ...          ...
# 1254            No             No       Yes            NaN          Yes
# 1255            No            Yes       Yes          Often          Yes
# 1256            No            Yes       Yes      Sometimes          Yes
# 1257            No             No        No            NaN          Yes
# 1258            No            Yes       Yes      Sometimes           No
#
#         benefits care_options wellness_program   seek_help
# 20           Yes          Yes               No          No
# 22           Yes          Yes               No          No
# 23    Don't know           No               No  Don't know
# 24           Yes     Not sure       Don't know         Yes
# 25           Yes          Yes               No  Don't know
# ...          ...          ...              ...         ...
# 1254          No           No               No          No
# 1255         Yes          Yes               No          No
# 1256         Yes          Yes               No          No
# 1257          No          Yes               No          No
# 1258         Yes          Yes               No          No
#
# [1095 rows x 9 columns]

# %%
mh_cleaned = mh_cleaned[mh_cleaned['tech_company'].str.find('No') == -1]
mh_cleaned
# Out:
#      self_employed family_history treatment work_interfere tech_company  \
# 20              No            Yes       Yes      Sometimes          Yes
# 22              No             No       Yes          Often          Yes
# 24              No            Yes       Yes         Rarely          Yes
# 26              No             No        No            NaN          Yes
# 27              No            Yes       Yes         Rarely          Yes
# ...            ...            ...       ...            ...          ...
# 1252            No            Yes       Yes      Sometimes          Yes
# 1254            No             No       Yes            NaN          Yes
# 1255            No            Yes       Yes          Often          Yes
# 1256            No            Yes       Yes      Sometimes          Yes
# 1257            No             No        No            NaN          Yes
#
#         benefits care_options wellness_program   seek_help
# 20           Yes          Yes               No          No
# 22           Yes          Yes               No          No
# 24           Yes     Not sure       Don't know         Yes
# 26    Don't know     Not sure               No  Don't know
# 27           Yes          Yes       Don't know  Don't know
# ...          ...          ...              ...         ...
# 1252         Yes          Yes              Yes          No
# 1254          No           No               No          No
# 1255         Yes          Yes               No          No
# 1256         Yes          Yes               No          No
# 1257          No          Yes               No          No
#
# [883 rows x 9 columns]

# %%
# removing missing values
mh_cleaned = mh_cleaned.dropna(axis=0, how='any').reset_index()
mh_cleaned
# Out:
#      index self_employed family_history treatment work_interfere tech_company  \
# 0       20            No            Yes       Yes      Sometimes          Yes
# 1       22            No             No       Yes          Often          Yes
# 2       24            No            Yes       Yes         Rarely          Yes
# 3       27            No            Yes       Yes         Rarely          Yes
# 4       28            No             No       Yes      Sometimes          Yes
# ..     ...           ...            ...       ...            ...          ...
# 682   1248            No            Yes       Yes      Sometimes          Yes
# 683   1249            No            Yes       Yes      Sometimes          Yes
# 684   1252            No            Yes       Yes      Sometimes          Yes
# 685   1255            No            Yes       Yes          Often          Yes
# 686   1256            No            Yes       Yes      Sometimes          Yes
#
#        benefits care_options wellness_program   seek_help
# 0           Yes          Yes               No          No
# 1           Yes          Yes               No          No
# 2           Yes     Not sure       Don't know         Yes
# 3           Yes          Yes       Don't know  Don't know
# 4    Don't know     Not sure               No  Don't know
# ..          ...          ...              ...         ...
# 682         Yes           No               No  Don't know
# 683         Yes          Yes       Don't know          No
# 684         Yes          Yes              Yes          No
# 685         Yes          Yes               No          No
# 686         Yes          Yes               No          No
#
# [687 rows x 10 columns]

# %%
# dropping unneeded columns
mh_cleaned = mh_cleaned.drop(['index', 'self_employed', 'tech_company'], axis=1)
mh_cleaned
# Out:
#     family_history treatment work_interfere    benefits care_options  \
# 0              Yes       Yes      Sometimes         Yes          Yes
# 1               No       Yes          Often         Yes          Yes
# 2              Yes       Yes         Rarely         Yes     Not sure
# 3              Yes       Yes         Rarely         Yes          Yes
# 4               No       Yes      Sometimes  Don't know     Not sure
# ..             ...       ...            ...         ...          ...
# 682            Yes       Yes      Sometimes         Yes           No
# 683            Yes       Yes      Sometimes         Yes          Yes
# 684            Yes       Yes      Sometimes         Yes          Yes
# 685            Yes       Yes          Often         Yes          Yes
# 686            Yes       Yes      Sometimes         Yes          Yes
#
#     wellness_program   seek_help
# 0                 No          No
# 1                 No          No
# 2         Don't know         Yes
# 3         Don't know  Don't know
# 4                 No  Don't know
# ..               ...         ...
# 682               No  Don't know
# 683       Don't know          No
# 684              Yes          No
# 685               No          No
# 686               No          No
#
# [687 rows x 7 columns]

# %% [markdown]
# ## Processing

# %%
# finding and replacing operations

def code_mcq(df,col):
    for o in df[col].unique():
        if o == 'Not sure' or o == "Don't know":
            df[col] = df[col].replace(o, 0)
            
        if o == 'Yes':
            df[col] = df[col].replace(o, 1)
                
        if o == 'No':
            df[col] = df[col].replace(o, 2)
        
    return df

# %%
code_mcq(mh_cleaned, 'benefits')
code_mcq(mh_cleaned, 'care_options')
code_mcq(mh_cleaned, 'wellness_program')
code_mcq(mh_cleaned, 'seek_help')
# Out:
#     family_history treatment work_interfere  benefits  care_options  \
# 0              Yes       Yes      Sometimes         1             1
# 1               No       Yes          Often         1             1
# 2              Yes       Yes         Rarely         1             0
# 3              Yes       Yes         Rarely         1             1
# 4               No       Yes      Sometimes         0             0
# ..             ...       ...            ...       ...           ...
# 682            Yes       Yes      Sometimes         1             2
# 683            Yes       Yes      Sometimes         1             1
# 684            Yes       Yes      Sometimes         1             1
# 685            Yes       Yes          Often         1             1
# 686            Yes       Yes      Sometimes         1             1
#
#      wellness_program  seek_help
# 0                   2          2
# 1                   2          2
# 2                   0          1
# 3                   0          0
# 4                   2          0
# ..                ...        ...
# 682                 2          0
# 683                 0          2
# 684                 1          2
# 685                 2          2
# 686                 2          2
#
# [687 rows x 7 columns]

# %%
mh_cleaned.to_csv('../../data/processed/mh_cleaned_gc.csv', index=None)

# %% [markdown]
# # Method Chaining

# %%
# initial filtering of rows and columns
mh0 = (
    pd.read_csv('../../data/raw/mentalhealthintech.csv')
       .loc[:, ['self_employed', 'family_history', 'treatment', 'work_interfere', 'tech_company', 'benefits', 'care_options', 'wellness_program', 'seek_help']]
       .loc[lambda row : row['self_employed'].str.find('Yes')== -1]
       .loc[lambda row : row['tech_company'].str.find('No') == -1]
      )

mh0
# Out:
#      self_employed family_history treatment work_interfere tech_company  \
# 20              No            Yes       Yes      Sometimes          Yes
# 22              No             No       Yes          Often          Yes
# 24              No            Yes       Yes         Rarely          Yes
# 26              No             No        No            NaN          Yes
# 27              No            Yes       Yes         Rarely          Yes
# ...            ...            ...       ...            ...          ...
# 1252            No            Yes       Yes      Sometimes          Yes
# 1254            No             No       Yes            NaN          Yes
# 1255            No            Yes       Yes          Often          Yes
# 1256            No            Yes       Yes      Sometimes          Yes
# 1257            No             No        No            NaN          Yes
#
#         benefits care_options wellness_program   seek_help
# 20           Yes          Yes               No          No
# 22           Yes          Yes               No          No
# 24           Yes     Not sure       Don't know         Yes
# 26    Don't know     Not sure               No  Don't know
# 27           Yes          Yes       Don't know  Don't know
# ...          ...          ...              ...         ...
# 1252         Yes          Yes              Yes          No
# 1254          No           No               No          No
# 1255         Yes          Yes               No          No
# 1256         Yes          Yes               No          No
# 1257          No          Yes               No          No
#
# [883 rows x 9 columns]

# %%
# handling missing data and removing more undesired columns
mh0 = (
    mh0.dropna(axis=0, how='any')
    .reset_index()
    .drop(['index', 'self_employed', 'tech_company'], axis=1)
      )

mh0
# Out:
#     family_history treatment work_interfere    benefits care_options  \
# 0              Yes       Yes      Sometimes         Yes          Yes
# 1               No       Yes          Often         Yes          Yes
# 2              Yes       Yes         Rarely         Yes     Not sure
# 3              Yes       Yes         Rarely         Yes          Yes
# 4               No       Yes      Sometimes  Don't know     Not sure
# ..             ...       ...            ...         ...          ...
# 682            Yes       Yes      Sometimes         Yes           No
# 683            Yes       Yes      Sometimes         Yes          Yes
# 684            Yes       Yes      Sometimes         Yes          Yes
# 685            Yes       Yes          Often         Yes          Yes
# 686            Yes       Yes      Sometimes         Yes          Yes
#
#     wellness_program   seek_help
# 0                 No          No
# 1                 No          No
# 2         Don't know         Yes
# 3         Don't know  Don't know
# 4                 No  Don't know
# ..               ...         ...
# 682               No  Don't know
# 683       Don't know          No
# 684              Yes          No
# 685               No          No
# 686               No          No
#
# [687 rows x 7 columns]

# %%
# coding response options
mh0 = (
    mh0.pipe(code_mcq, col='benefits')
    .pipe(code_mcq, col='care_options')
    .pipe(code_mcq, col='wellness_program')
    .pipe(code_mcq, col='seek_help')
      )

mh0
# Out:
#     family_history treatment work_interfere  benefits  care_options  \
# 0              Yes       Yes      Sometimes         1             1
# 1               No       Yes          Often         1             1
# 2              Yes       Yes         Rarely         1             0
# 3              Yes       Yes         Rarely         1             1
# 4               No       Yes      Sometimes         0             0
# ..             ...       ...            ...       ...           ...
# 682            Yes       Yes      Sometimes         1             2
# 683            Yes       Yes      Sometimes         1             1
# 684            Yes       Yes      Sometimes         1             1
# 685            Yes       Yes          Often         1             1
# 686            Yes       Yes      Sometimes         1             1
#
#      wellness_program  seek_help
# 0                   2          2
# 1                   2          2
# 2                   0          1
# 3                   0          0
# 4                   2          0
# ..                ...        ...
# 682                 2          0
# 683                 0          2
# 684                 1          2
# 685                 2          2
# 686                 2          2
#
# [687 rows x 7 columns]

# %%
def load_and_process(url_or_filepath):
    
    # method chain 1: initial filtering of rows and columns
    
    df1 = (
    pd.read_csv(url_or_filepath)
       .loc[:, ['self_employed', 'family_history', 'treatment', 'work_interfere', 'tech_company', 'benefits', 'care_options', 'wellness_program', 'seek_help']]
       .loc[lambda row : row['self_employed'].str.find('Yes')== -1]
       .loc[lambda row : row['tech_company'].str.find('No') == -1]
      )
    
    # method chain 2: handling missing data and removing more undesired columns
    
    df2 = (
    df1.dropna(axis=0, how='any')
    .reset_index()
    .drop(['index', 'self_employed', 'tech_company'], axis=1)
      )
    
    # method chain 3: coding response options
    
    df3 = (
    df2.pipe(code_mcq, col='benefits')
    .pipe(code_mcq, col='care_options')
    .pipe(code_mcq, col='wellness_program')
    .pipe(code_mcq, col='seek_help')
      )
    
    return df3

# %%
mh0 = load_and_process('../../data/raw/mentalhealthintech.csv')
mh0.head()
# Out:
#   family_history treatment work_interfere  benefits  care_options  \
# 0            Yes       Yes      Sometimes         1             1
# 1             No       Yes          Often         1             1
# 2            Yes       Yes         Rarely         1             0
# 3            Yes       Yes         Rarely         1             1
# 4             No       Yes      Sometimes         0             0
#
#    wellness_program  seek_help
# 0                 2          2
# 1                 2          2
# 2                 0          1
# 3                 0          0
# 4                 2          0

# %% [markdown]
# ## Testing new function

# %%
from scripts import project_functions_gc as pfg

# %%
mh0 = pfg.load_and_process('../../data/raw/mentalhealthintech.csv')
mh0
# Out:
#     family_history treatment work_interfere  benefits  care_options  \
# 0              Yes       Yes      Sometimes         1             1
# 1               No       Yes          Often         1             1
# 2              Yes       Yes         Rarely         1             0
# 3              Yes       Yes         Rarely         1             1
# 4               No       Yes      Sometimes         0             0
# ..             ...       ...            ...       ...           ...
# 682            Yes       Yes      Sometimes         1             2
# 683            Yes       Yes      Sometimes         1             1
# 684            Yes       Yes      Sometimes         1             1
# 685            Yes       Yes          Often         1             1
# 686            Yes       Yes      Sometimes         1             1
#
#      wellness_program  seek_help
# 0                   2          2
# 1                   2          2
# 2                   0          1
# 3                   0          0
# 4                   2          0
# ..                ...        ...
# 682                 2          0
# 683                 0          2
# 684                 1          2
# 685                 2          2
# 686                 2          2
#
# [687 rows x 7 columns]
